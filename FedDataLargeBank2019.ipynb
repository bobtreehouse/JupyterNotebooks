# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
Fed_data = pd.read_csv('FedDataLargeBank_2.csv')

# %%
Fed_data
# Out:
#                                                 Type       2017       2018  \
# 0                                                NaN        Dec        Jun
# 1                                        Bank credit   7,327.3    7,299.9
# 2                        Securities in bank credit 2   2,256.1    2,206.3
# 3                   Treasury and agency securities 3   1,724.8    1,717.5
# 4                 Mortgage-backed securities (MBS) 4   1,297.4    1,294.9
# 5                                          Non-MBS 5     427.4      422.6
# 6                                   Other securities     531.3      488.8
# 7                 Mortgage-backed securities (MBS) 6      66.2       61.8
# 8                                          Non-MBS 7     465.1      427.0
# 9                  Loans and leases in bank credit 8   5,071.2    5,093.6
# 10                   Commercial and industrial loans   1,145.8    1,185.4
# 11                                 Real estate loans   2,064.9    2,048.7
# ...

# %%
treas= Fed_data[Fed_data.Type == 'Treasury and agency securities 3']

# %%
treas
# Out:
# Empty DataFrame
# Columns: [Type, 2017, 2018, 2018.1, 2018.2, 2018.3, 2018.4, 2018.5, 2018.6, 2018.7, 2019, 2019.1, 2019.2]
# Index: []

# %%
plt.plot(x,y)
plt.title("Res Loans Past 2 years")
plt.xlabel("Date")
plt.ylabel("Res Loans 2017 - 2019")
plt.legend(["Res", "Time"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3616ecb77126> in <module>()
# ----> 1 plt.plot(x,y)
#       2 plt.title("Res Loans Past 2 years")
#       3 plt.xlabel("Date")
#       4 plt.ylabel("Res Loans 2017 - 2019")
#       5 plt.legend(["Res", "Time"])
#
# NameError: name 'x' is not defined
